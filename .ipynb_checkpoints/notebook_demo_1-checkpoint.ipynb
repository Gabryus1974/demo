# %%
# !pip install oracle-ads[data]
# Out:
# Requirement already satisfied: oracle-ads[data] in /opt/conda/lib/python3.11/site-packages (2.14.4)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (6.0.2)
# Requirement already satisfied: asteval>=0.9.25 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (1.0.8)
# Requirement already satisfied: cerberus>=1.3.4 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (1.3.4)
# Requirement already satisfied: cloudpickle>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (3.1.2)
# Requirement already satisfied: fsspec>=0.8.7 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (2026.1.0)
# Requirement already satisfied: gitpython>=3.1.2 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (3.1.46)
# Requirement already satisfied: jinja2>=2.11.2 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (3.1.6)
# Requirement already satisfied: matplotlib>=3.1.3 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (3.10.8)
# Requirement already satisfied: numpy>=1.19.2 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (1.26.4)
# Requirement already satisfied: oci>=2.148.0 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (2.165.1)
# Requirement already satisfied: ocifs>=1.1.3 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (1.3.4)
# Requirement already satisfied: pandas>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (3.0.0)
# Requirement already satisfied: psutil>=5.7.2 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (7.2.1)
# Requirement already satisfied: python_jsonschema_objects>=0.3.13 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (0.5.7)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (2.32.5)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (1.8.0)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (0.9.0)
# Requirement already satisfied: tqdm>=4.59.0 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (4.67.1)
# Requirement already satisfied: pydantic>=2.6.3 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (2.12.5)
# Requirement already satisfied: tenacity in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (8.5.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (0.28.1)
# Collecting datefinder>=0.7.1 (from oracle-ads[data])
#   Downloading datefinder-0.7.3-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: fastavro>=0.24.2 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (1.12.1)
# Collecting htmllistparse>=0.6.0 (from oracle-ads[data])
#   Downloading htmllistparse-0.6.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting openpyxl>=3.0.7 (from oracle-ads[data])
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: oracledb>=1.0 in /opt/conda/lib/python3.11/site-packages (from oracle-ads[data]) (1.4.2)
# Collecting pandavro>=1.6.0 (from oracle-ads[data])
#   Downloading pandavro-1.9.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting sqlalchemy<=1.4.46,>=1.4.1 (from oracle-ads[data])
#   Downloading SQLAlchemy-1.4.46-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy<=1.4.46,>=1.4.1->oracle-ads[data]) (3.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from cerberus>=1.3.4->oracle-ads[data]) (80.10.1)
# Requirement already satisfied: regex>=2017.02.08 in /opt/conda/lib/python3.11/site-packages (from datefinder>=0.7.1->oracle-ads[data]) (2026.1.15)
# Requirement already satisfied: python-dateutil>=2.4.2 in /opt/conda/lib/python3.11/site-packages (from datefinder>=0.7.1->oracle-ads[data]) (2.9.0.post0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from datefinder>=0.7.1->oracle-ads[data]) (2025.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython>=3.1.2->oracle-ads[data]) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.2->oracle-ads[data]) (5.0.2)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from htmllistparse>=0.6.0->oracle-ads[data]) (4.14.3)
# Collecting fusepy (from htmllistparse>=0.6.0->oracle-ads[data])
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting html5lib (from htmllistparse>=0.6.0->oracle-ads[data])
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=2.11.2->oracle-ads[data]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.1.3->oracle-ads[data]) (3.3.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from oci>=2.148.0->oracle-ads[data]) (2026.1.4)
# Requirement already satisfied: cryptography<46.0.0,>=3.2.1 in /opt/conda/lib/python3.11/site-packages (from oci>=2.148.0->oracle-ads[data]) (45.0.7)
# Requirement already satisfied: pyOpenSSL<=25.1.0,>=17.5.0 in /opt/conda/lib/python3.11/site-packages (from oci>=2.148.0->oracle-ads[data]) (25.1.0)
# Requirement already satisfied: circuitbreaker<3.0.0,>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from oci>=2.148.0->oracle-ads[data]) (2.1.3)
# Requirement already satisfied: cffi>=1.14 in /opt/conda/lib/python3.11/site-packages (from cryptography<46.0.0,>=3.2.1->oci>=2.148.0->oracle-ads[data]) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.9 in /opt/conda/lib/python3.11/site-packages (from pyOpenSSL<=25.1.0,>=17.5.0->oci>=2.148.0->oracle-ads[data]) (4.15.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.4.2->datefinder>=0.7.1->oracle-ads[data]) (1.17.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.14->cryptography<46.0.0,>=3.2.1->oci>=2.148.0->oracle-ads[data]) (2.21)
# Collecting et-xmlfile (from openpyxl>=3.0.7->oracle-ads[data])
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pandas>=2.2.0 (from oracle-ads[data])
#   Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.19.2 (from oracle-ads[data])
#   Downloading numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2.0->oracle-ads[data]) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.6.3->oracle-ads[data]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.6.3->oracle-ads[data]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.6.3->oracle-ads[data]) (0.4.2)
# Requirement already satisfied: inflection>=0.2 in /opt/conda/lib/python3.11/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads[data]) (0.5.1)
# Requirement already satisfied: Markdown>=2.4 in /opt/conda/lib/python3.11/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads[data]) (3.10.1)
# Requirement already satisfied: jsonschema>=4.18 in /opt/conda/lib/python3.11/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads[data]) (4.26.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads[data]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads[data]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads[data]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18->python_jsonschema_objects>=0.3.13->oracle-ads[data]) (0.30.0)
# Requirement already satisfied: scipy>=1.10.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0->oracle-ads[data]) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0->oracle-ads[data]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0->oracle-ads[data]) (3.6.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->htmllistparse>=0.6.0->oracle-ads[data]) (2.8.3)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from html5lib->htmllistparse>=0.6.0->oracle-ads[data]) (0.5.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx->oracle-ads[data]) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx->oracle-ads[data]) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx->oracle-ads[data]) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx->oracle-ads[data]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->oracle-ads[data]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->oracle-ads[data]) (2.6.3)
# Downloading SQLAlchemy-1.4.46-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.1 MB/s  0:00:00
# Downloading datefinder-0.7.3-py2.py3-none-any.whl (10 kB)
# Downloading htmllistparse-0.6.1-py3-none-any.whl (10.0 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading pandavro-1.9.0-py3-none-any.whl (9.0 kB)
# Downloading numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 68.4 MB/s  0:00:006m0:00:01
# Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 76.3 MB/s  0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (pyproject.toml) ... done
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10538 sha256=2852affb44077e691841d0a7494465beb408d693c78ee7e1fb9ab94872548288
#   Stored in directory: /home/datascience/.cache/pip/wheels/db/4a/86/fdda91f8b8ebb0a70e4181dc2423b1f70c3c2d3bd1158685b5
# Successfully built fusepy
# Installing collected packages: fusepy, sqlalchemy, numpy, html5lib, et-xmlfile, pandas, openpyxl, htmllistparse, datefinder, pandavro
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.46
#     Uninstalling SQLAlchemy-2.0.46:
#       Successfully uninstalled SQLAlchemy-2.0.46
#   Attempting uninstall: numpy0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/10 [sqlalchemy]
#     Found existing installation: numpy 1.26.4━━━━━━━━━━━━━━━━━  1/10 [sqlalchemy]
#     Uninstalling numpy-1.26.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/10 [numpy]]
#       Successfully uninstalled numpy-1.26.4━━━━━━━━━━━━━━━━━━━  2/10 [numpy]
#   Attempting uninstall: pandas━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/10 [html5lib]
#     Found existing installation: pandas 3.0.0━━━━━━━━━━━━━━━━━  3/10 [html5lib]
#     Uninstalling pandas-3.0.0:0m╺━━━━━━━━━━━━━━━━━━━  5/10 [pandas]
#       Successfully uninstalled pandas-3.0.0━━━━━━━━━━━━━━━━━━━  5/10 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [pandavro]/10 [openpyxl]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-aws 0.2.35 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.4.3 which is incompatible.
# Successfully installed datefinder-0.7.3 et-xmlfile-2.0.0 fusepy-3.0.1 html5lib-1.1 htmllistparse-0.6.1 numpy-2.4.3 openpyxl-3.1.5 pandas-2.3.3 pandavro-1.9.0 sqlalchemy-1.4.46

# %%
import ads
from ads.dataset.factory import DatasetFactory
# Out:
# /opt/conda/lib/python3.11/site-packages/cerberus/__init__.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
ads.set_auth(auth="resource_principal")

# %%
bucket_name = "ds-lab-bucket-01"
namespace = "ax9nj9bzjzwo"

employees = DatasetFactory.open(
    "oci://ds-lab-bucket-01@ax9nj9bzjzwo/datasets/orcl_attrition.csvorcl_attrition.csv",
    target="Attrition"
)
# Out:
# loop1:   0%|          | 0/4 [00:00<?, ?it/s]
# ERROR - Exception
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/ads/common/decorator/runtime_dependency.py", line 147, in wrapper
#     _module = importlib.import_module(module)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'datefinder'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_13866/340867411.py", line 4, in <module>
#     employees = DatasetFactory.open(
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/ads/common/decorator/deprecate.py", line 65, in wrapper
#     return target(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/ads/dataset/factory.py", line 221, in open
#     return DatasetFactory._build_dataset(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/ads/dataset/factory.py", line 553, in _build_dataset
#     target_type = DatasetFactory.infer_target_type(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/ads/dataset/factory.py", line 576, in infer_target_type
#     target_type = TypeDiscoveryDriver().discover(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/ads/type_discovery/type_discovery_driver.py", line 85, in discover
#     return utils.first_not_none(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/ads/common/utils.py", line 690, in first_not_none
#     for x in itr:
#   File "/opt/conda/lib/python3.11/site-packages/ads/type_discovery/type_discovery_driver.py", line 86, in <genexpr>
#     (plugin.discover(name, s) for plugin in discovery_plugins)
#      ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/ads/type_discovery/datetime_detector.py", line 53, in discover
#     fn = self._is_date_time(name, candidates.head(500), series.dtype.name)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/ads/common/decorator/runtime_dependency.py", line 164, in wrapper
#     raise ModuleNotFoundError(
# ModuleNotFoundError: The `datefinder` module was not found. Please run `pip install oracle-ads[data]`.
# ModuleNotFoundError: The `datefinder` module was not found. Please run `pip install oracle-ads[data]`.
